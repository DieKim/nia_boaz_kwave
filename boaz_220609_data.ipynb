# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/boaz
# Out:
# /content/drive/MyDrive/boaz

# %%
#데이터 리스트 확인
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import random
random.seed(1)
import warnings
warnings.filterwarnings(action='ignore')
pd.set_option('display.max_columns', None)
path = '/content/drive/MyDrive/boaz'
name_list = os.listdir(path + '/BOAZXNIA')
print(len(name_list))
for idx, name in enumerate(name_list):
  print(idx+1, name)
# Out:
# 31
# 1 TN_K_DRAMA_CST_AUDERT_INFO_202108.csv
# 2 TN_K_DRAMA_CST_AUDERT_INFO_202107.csv
# 3 TN_K_DRAMA_CST_AUDERT_INFO_202104.csv
# 4 TN_K_DRAMA_CST_AUDERT_INFO_202105.csv
# 5 TN_K_DRAMA_CST_AUDERT_INFO_202101.csv
# 6 TN_K_DRAMA_CST_AUDERT_INFO_202111.csv
# 7 TN_K_DRAMA_CST_AUDERT_INFO_202112.csv
# 8 TN_K_DRAMA_CST_AUDERT_INFO_202110.csv
# 9 TN_K_DRAMA_CST_AUDERT_INFO_202012.csv
# 10 TN_K_DRAMA_CST_AUDERT_INFO_202011.csv
# 11 TN_K_DRAMA_CST_AUDERT_INFO_202109.csv
# 12 KC_music_chart_us_2019.csv
# 13 KC_music_chart_vn_2019.csv
# 14 KC_music_chart_gb_2019.csv
# 15 KC_music_chart_au_2019.csv
# 16 ANTI_SYMPATHY_INFO_2021(반한류).csv
# 17 SVC_USE_INTEN_INFO_2021(제품및서비스사용의향).csv
# 18 HOPE_KSTAR_INFO_2021(만나고싶은한류스타).csv
# 19 CLTUR_CNTNTS_GENRE_OBSTRC_FCTR_INFO_2021(장르별저해요인).csv
# 20 KC_YOUTUBE_VIEW_US_2019.csv
# 21 KC_YOUTUBE_VIEW_VN_2019.csv
# 22 KC_YOUTUBE_VIEW_AU_2019.csv
# 23 KC_YOUTUBE_VIEW_GB_2019.csv
# 24 KC_YOUTUBE_VIEW_ID_2019.csv
# ...

# %%
#모든 데이터 불러오기
for idx, name in enumerate(name_list):
  globals()['df{}'.format(idx+1)] = pd.read_csv(path+'/BOAZXNIA/'+name)

# %%
#K-드라마 프로그램, 출연진정보, 채널, 시청률 등의 TV 콘텐츠 DB 데이터
display(df1)
print(df1.columns)
# Out:
#       BRDCST_DE  BRDCST_END_DE  CHNNEL_NM  PROGRM_BEGIN_TIME  PROGRM_END_TIME  \
# 0      20210801       20210801        SBS              20000            31445
# 1      20210801       20210801  TV CHOSUN             153041           164014
# 2      20210801       20210801  TV CHOSUN             211310           214329
# 3      20210801       20210801  TV CHOSUN             214448           222525
# 4      20210801       20210801        tvN              20000            24914
# ...         ...            ...        ...                ...              ...
# 4693   20210831       20210831  JNG KOREA              65928            74720
# 4694   20210831       20210831  JNG KOREA             110216           113429
# 4695   20210831       20210831  JNG KOREA             114812           121936
# 4696   20210831       20210901  JNG KOREA             233007             1704
# 4697   20210901       20210901  JNG KOREA               2906            11642
#
# ...

# %% [markdown]
# * 문제: 20.11-21.12 월별 데이터인데 중간에 데이터가 없는 달이 존재

# %%
#5개국 음원순위 데이터
display(df12)
print(df12.columns)
# Out:
#      Survey_Base_Date_DE Country_CD      Music_NM                 Artist_NM  \
# 0             2020-01-07         us        Younha  Winter Flower (feat. RM)
# 1             2020-01-07         us         ATEEZ                    Answer
# 2             2020-01-07         us         ATEEZ                   Horizon
# 3             2020-01-07         us    Red Velvet                    Psycho
# 4             2020-01-07         us         ATEEZ                  Precious
# ...                  ...        ...           ...                       ...
# 2195          2020-01-28         us         Ailee         Just Look for You
# 2196          2020-01-28         us           BTS                       DNA
# 2197          2020-01-28         us           BTS                    Danger
# 2198          2020-01-28         us  GD X TAEYANG                  GOOD BOY
# 2199          2020-01-28         us          GOT7                Just Right
#
#       Music_RN               FILE_NAME  BASE_YMD
# ...

# %% [markdown]
# * 문제: 20.01.07-20.01.28

# %%
#5개국 유튜브 데이터
display(df20)
print(df20.columns)
# Out:
#     Survey_Date_DE Country_CD         Artist_NM  Views_CO  \
# 0       2019-12-16         us        BTS(방탄소년단)   1059194
# 1       2019-12-16         us         Blackpink    399085
# 2       2019-12-16         us       TWICE(트와이스)    311839
# 3       2019-12-16         us           EXO(엑소)    234232
# 4       2019-12-16         us     MAMAMOO (마마무)    194163
# ..             ...        ...               ...       ...
# 527     2020-01-12         us               CLC     30865
# 528     2020-01-12         us     IZ*ONE (아이즈원)     22055
# 529     2020-01-12         us            WINNER     16309
# 530     2020-01-12         us               NCT     10165
# 531     2020-01-12         us  오마이걸(OH MY GIRL)      9541
#
#                    FILE_NAME  BASE_YMD
# 0    KC_YOUTUBE_VIEW_US_2019      2019
# 1    KC_YOUTUBE_VIEW_US_2019      2019
# 2    KC_YOUTUBE_VIEW_US_2019      2019
# 3    KC_YOUTUBE_VIEW_US_2019      2019
# 4    KC_YOUTUBE_VIEW_US_2019      2019
# ...

# %% [markdown]
# * 문제: 19.12.16-20.01.12

# %%
#트위터 키워드 - 팬클럽
display(df29)
print(df29.columns)
# Out:
#      Social_Data_Collection_Date_YM Collection_CH_NM Artist_NM Fanclub_NM  \
# 0                           2017-01          Twitter       BTS       army
# 1                           2017-01          Twitter       BTS       army
# 2                           2017-01          Twitter       BTS       army
# 3                           2017-01          Twitter       BTS       army
# 4                           2017-01          Twitter       BTS       army
# ...                             ...              ...       ...        ...
# 3347                        2019-11          Twitter      itzy      midzy
# 3348                        2019-11          Twitter      itzy      midzy
# 3349                        2019-11          Twitter      itzy      midzy
# 3350                        2019-11          Twitter      itzy      midzy
# 3351                        2019-11          Twitter      itzy      midzy
#
#           Twitter_KEY_W  Keyword_FQ                        FILE_NAME  BASE_YMD
# ...

# %%
#트위터 키워드 - 아티스트
display(df30)
print(df30.columns)
# Out:
#      Social_Data_Collection_Date_YM Collection_CH_NM Artist_NM Twitter_KEY_W  \
# 0                           2017-01          Twitter      day6         watch
# 1                           2017-01          Twitter      day6         first
# 2                           2017-01          Twitter      day6         video
# 3                           2017-01          Twitter      day6         month
# 4                           2017-01          Twitter      day6          like
# ...                             ...              ...       ...           ...
# 7435                        2019-11          Twitter     ateez           exo
# 7436                        2019-11          Twitter     ateez           txt
# 7437                        2019-11          Twitter     ateez         sugar
# 7438                        2019-11          Twitter     ateez      giveaway
# 7439                        2019-11          Twitter     ateez        friend
#
# ...

# %%
#트위터 키워드 - 기획사
display(df31)
print(df31.columns)
# Out:
#      Social_Data_Collection_Date_YM Collection_CH_NM Entertainment_NM  \
# 0                           2017-01          Twitter               yg
# 1                           2017-01          Twitter               yg
# 2                           2017-01          Twitter               yg
# 3                           2017-01          Twitter               yg
# 4                           2017-01          Twitter               yg
# ...                             ...              ...              ...
# 3868                        2019-11          Twitter               sm
# 3869                        2019-11          Twitter               sm
# 3870                        2019-11          Twitter               sm
# 3871                        2019-11          Twitter               sm
# 3872                        2019-11          Twitter               sm
#
#      Twitter_KEY_W  Keyword_FQ                              FILE_NAME  \
# ...

# %%
#만나고싶은한류스타
display(df18)
print(df18.columns)
# Out:
#      STAR_NM  MALE_RATE  FEMALE_RATE  ALL_N10S_RATE  ALL_N20S_RATE  \
# 0        이민호        6.8          9.6           10.4            8.8
# 1        전지현        9.2          6.8            8.0            5.6
# 2        송혜교        6.4          8.0            3.2            7.2
# 3        송중기        4.8          8.4            9.6           11.2
# 4        김희선        5.2          4.0            0.0            2.4
# ...      ...        ...          ...            ...            ...
# 1141    블랙핑크        5.7          7.4            5.7           12.8
# 1142      싸이        5.7          6.3            3.8            4.3
# 1143    지드래곤        2.3          3.2            0.0            4.3
# 1144      엑소        2.3          2.1            3.8            2.1
# 1145  전정국/정국        2.3          0.0            0.0            2.1
#
#       ALL_N30S_RATE  ALL_N40S_RATE  ALL_N50S_RATE  REPRT_YEAR_CN  \
# 0               4.8            9.0            8.0           2019
# ...

# %% [markdown]
# * 가수+배우 통합

# %%
#문화컨텐츠소비비중 
display(df25)
print(df25.columns)
# Out:
#                IEM_NM  ALL_TOTAL_CO  MALE_RATE  FEMALE_RATE  ALL_N10S_RATE  \
# 0     한국 문화콘텐츠 소비(시간)            18      16.65        19.69          22.03
# 1            소비 비중(%)            29      27.92        30.80          29.99
# 2        월평균 지출 금액($)             7       8.12         6.82           6.08
# 3     한국 문화콘텐츠 소비(시간)            13      11.76        14.76          14.25
# 4            소비 비중(%)            28      25.52        31.29          24.85
# ...               ...           ...        ...          ...            ...
# 2593     월평균 지출 금액($)             9       8.50         8.57           8.80
# 2594         소비 비중(%)            19      20.35        18.02          17.82
# 2595     월평균 지출 금액($)             8       9.01         8.17           9.34
# 2596         소비 비중(%)            13      13.58        12.95          15.45
# 2597     월평균 지출 금액($)             8       8.31         7.95           9.89
#
#       ALL_N20S_RATE  ALL_N30S_RATE  ALL_N40S_RATE  ALL_N50S_RATE  \
# ...

# %%
#컨텐츠호감도인기도
display(df26)
print(df26.columns)
# Out:
#                   POPULAR_DGREE_CN  ALL_TOTAL_CO  MALE_RATE  FEMALE_RATE  \
# 0                           대중적 인기            34       34.0         34.8
# 1                            보통 인기            39       36.4         40.8
# 2                        소수 마니아 인기            23       26.4         20.4
# 3                         거의 이용 안함             4        3.2          4.0
# 4                           대중적 인기            33       30.8         34.4
# ...                            ...           ...        ...          ...
# 3621                이용하는 사람이 거의 없다            12       14.5          9.5
# 3622           일부 매니아증에서 인기가 있는 상태            16       17.0         15.0
# 3623   일부 매니아층 뿐만 아니라 일반인들도 상당수 인지            33       33.5         32.0
# 3624    일반인에게 널리 알려져 있고 관련 상품이 판매됨            23       20.5         25.5
# 3625  일반인에게 널리 인기 있고 관련 상품의 판매가 원활            16       14.5         18.0
#
#       ALL_N10S_RATE  ALL_N20S_RATE  ALL_N30S_RATE  ALL_N40S_RATE  \
# ...

# %%
#한국연상이미지
display(df27)
print(df27.columns)
# Out:
#                  IMAGE_NM  MALE_RATE  FEMALE_RATE  ALL_N10S_RATE  \
# 0     한국 음식(김치, 김, 볼고기 등)       16.4         16.4           18.4
# 1                     드라마       10.8         12.0           14.4
# 2              뷰티 서비스(성형)        7.2         10.0            9.6
# 3              뷰티 제품(화장품)        4.0          7.6            8.0
# 4                 한글(한국어)        4.0          6.8            4.8
# ...                   ...        ...          ...            ...
# 2271                   북한        4.5          3.0            1.0
# 2272                   영화        4.5          2.5            3.0
# 2273                  태권도        4.5          1.0            1.0
# 2274                  관광지        3.5          2.0            5.0
# 2275                 한국전쟁        1.0          4.0            0.0
#
#       ALL_N20S_RATE  ALL_N30S_RATE  ALL_N40S_RATE  ALL_N50S_RATE  \
# 0              16.0           19.2           10.1           16.7
# ...

# %%
#제품및서비스사용의향
display(df17)
print(df17.columns)
# Out:
#               USE_CN  ALL_TOTAL_CO  MALE_RATE  FEMALE_RATE  ALL_N10S_RATE  \
# 0       전반적 한국 제품 구매             4       3.57         3.53           3.53
# 1           한국 식품 구매             4       3.82         3.86           3.71
# 2           한국 의류 구매             4       3.65         3.64           3.43
# 3          한국 화장품 구매             4       3.74         3.86           3.66
# 4           한국 주류 구매             3       3.57         3.37           3.34
# ..               ...           ...        ...          ...            ...
# 829     전반적 한국 제품 구매             4       3.57         3.43           3.44
# 830  잘 모르는 한국 브랜드 구매             3       3.20         3.24           3.14
# 831            한글 학습             3       3.15         3.29           3.36
# 832           태권도 학습             3       3.30         3.33           3.39
# 833       한국 전통문화 체험             4       3.53         3.66           3.66
#
#      ALL_N20S_RATE  ALL_N30S_RATE  ALL_N40S_RATE  ALL_N50S_RATE  \
# ...

# %%
#반한류
display(df16)
print(df16.columns)
# Out:
#                       CAUSE_CN  MALE_RATE  FEMALE_RATE  ALL_N10S_RATE  \
# 0                    지나치게 상업적임       15.9         23.5           21.6
# 1         한류스타?유명인의 부적절한 언행 때문       15.0         13.6           15.7
# 2            한국과의 정치?외교적 갈등 때문       12.4          9.9            3.9
# 3               한국의 국민성이 좋지 않음       11.5         11.1            9.8
# 4               자국 콘텐츠 산업보호 필요       11.5          9.9           15.7
# ..                         ...        ...          ...            ...
# 744  남북 북단?북한의 국제적인위협 관련 보도 때문       12.1          8.3           11.8
# 745            한국과의 역사적인 관계 때문        9.1          4.2           11.8
# 746               지나치게 자극적?선정적        9.1          0.0            5.9
# 747          한국과의 정치?외교적 갈등 때문        6.1          0.0            0.0
# 748                         기타        6.1          0.0            5.9
#
#      ALL_N20S_RATE  ALL_N30S_RATE  ALL_N40S_RATE  ALL_N50S_RATE REPRT_YEAR_CN  \
# ...

# %%
#장르별저해요인
display(df19)
print(df19.columns)
# Out:
#                 OBSTRC_FCTR_CN  ALL_TOTAL_CO  MALE_RATE  FEMALE_RATE  \
# 0          소재,스토리,장르 등이 진부?획일적            17       16.0         18.4
# 1              자막?더빙 통한 시청 불편함            14       19.3          9.2
# 2                 한국어가 어렵고 생소함             8        8.0          7.9
# 3                     비용이 많이 듦             8        8.7          6.6
# 4                 한국적인 색채가 강해서             7        6.0          8.6
# ...                        ...           ...        ...          ...
# 5488   식당,직원의 위생?청결 상태가 좋지 않아서             7        5.0          9.6
# 5489                   불친절한 직원             7        7.6          7.0
# 5490  상차림?플레이팅?분위기가 마음에 들지 않아서             6       10.1          0.9
# 5491        자국과의 정치?외교적 관계로 인해             5        5.0          4.3
# 5492                        기타             2        0.8          2.6
#
#       ALL_N10S_RATE  ALL_N20S_RATE  ALL_N30S_RATE  ALL_N40S_RATE  \
# 0              12.6           21.1           20.0           19.4
# ...
